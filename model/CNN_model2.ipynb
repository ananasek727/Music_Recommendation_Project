# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.image as mpimg
import shutil
import random
import os
import datetime
import tensorflow as tf

from sklearn.utils import shuffle
from PIL import Image
from tensorflow.keras import regularizers
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Resizing, Rescaling, RandomFlip, RandomRotation, RandomBrightness, RandomContrast, BatchNormalization
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet_v2 import preprocess_input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import Input, Model
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
import json

# %%
path = "../FER2013_ver2"
emotions = os.listdir(f"{path}/train")

train_image = []
train_emotion = []

print("train data...")
for emotion in emotions:
    image_path = f"{path}/train/{emotion}"
    files = os.listdir(image_path)
    print(emotion)
    for file in files:
        img = cv2.imread(f"{image_path}/{file}")
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = cv2.resize(img, (48, 48))
        train_image.append(img)
        train_emotion.append(emotion)


test_image = []
test_emotion = []

print("test data...")
for emotion in emotions:
    image_path = f"{path}/test/{emotion}"
    files = os.listdir(image_path)
    print(emotion)
    for file in files:
        img = cv2.imread(f"{image_path}/{file}")
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = cv2.resize(img, (48, 48))
        test_image.append(img)
        test_emotion.append(emotion)


train_image = np.array(train_image)
train_emotion = np.array(train_emotion)
train_image, train_emotion = shuffle(train_image, train_emotion, random_state=0)

test_image = np.array(test_image)
test_emotion = np.array(test_emotion)
test_image, test_emotion = shuffle(test_image, test_emotion, random_state=0)
# Out:
# train data...
# angry
# disgust
# fear
# happy
# neutral
# sad
# surprise
# test data...
# angry
# disgust
# fear
# happy
# neutral
# sad
# surprise

# %%
print(train_image[5].shape)
print(train_emotion.shape)
print(test_image.shape)
print(test_emotion.shape)
print(train_emotion[5])
# Out:
# (48, 48)
# (3052,)
# (777, 48, 48)
# (777,)
# happy

# %%
label_map = {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
train_emotion_int = [label_map[label] for label in train_emotion]
train_emotion_int = np.array(train_emotion_int)

test_emotion_int = [label_map[label] for label in test_emotion]
test_emotion_int = np.array(test_emotion_int)

# %%
from keras.utils import to_categorical
train_emotion_onehot = to_categorical(train_emotion_int)
test_emotion_onehot = to_categorical(test_emotion_int)
print(train_emotion_onehot.shape)
print(test_emotion_onehot.shape)
print(train_emotion_onehot[4])
# Out:
# (3052, 7)
# (777, 7)
# [0. 0. 0. 0. 0. 1. 0.]

# %%
train_image = train_image.reshape((-1, 48, 48, 1))
test_image = test_image.reshape((-1, 48, 48, 1))

# %%
train_image.shape
# Out:
# (3052, 48, 48, 1)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                                  patience=15,
                                                  mode='max',
                                                  verbose=1,
                                                  restore_best_weights=True)


### INSPIRACJA https://www.analyticsvidhya.com/blog/2021/11/facial-emotion-detection-using-cnn/
model = Sequential()

model.add(Conv2D(64, (3,3), activation='relu', padding='same', input_shape=(48, 48, 1)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.3))

model.add(Flatten())

#mozna jeszcze dodać taki fragment np jakby był sredni wynik
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(7, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

history = model.fit(train_image, train_emotion_onehot, batch_size=32,
                    epochs = 100, validation_split = 0.1,
                    callbacks = [early_stopping])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 64)        640
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 48, 48, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 128)       147584
#
#  batch_normalization_4 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 256)       295168
#
#  batch_normalization_5 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batch_normalization_6 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batch_normalization_7 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 256)       590080
#
#  batch_normalization_8 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 256)         0
#
#  conv2d_9 (Conv2D)           (None, 6, 6, 256)         590080
#
#  batch_normalization_9 (Batc  (None, 6, 6, 256)        1024
#  hNormalization)
#
#  conv2d_10 (Conv2D)          (None, 6, 6, 256)         590080
#
#  batch_normalization_10 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 6, 6, 256)         590080
#
#  batch_normalization_11 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv2d_12 (Conv2D)          (None, 6, 6, 256)         590080
#
#  batch_normalization_12 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 256)         0
#
#  conv2d_13 (Conv2D)          (None, 3, 3, 512)         1180160
#
#  batch_normalization_13 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv2d_14 (Conv2D)          (None, 3, 3, 512)         2359808
#
#  batch_normalization_14 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv2d_15 (Conv2D)          (None, 3, 3, 512)         2359808
#
#  batch_normalization_15 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv2d_16 (Conv2D)          (None, 3, 3, 512)         2359808
#
#  batch_normalization_16 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 1, 1, 512)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 13,554,631
# Trainable params: 13,545,415
# Non-trainable params: 9,216
# _________________________________________________________________
# Epoch 1/100
# 86/86 [==============================] - 101s 1s/step - loss: 2.0402 - accuracy: 0.1482 - val_loss: 2.9203 - val_accuracy: 0.1078
# Epoch 2/100
# 86/86 [==============================] - 86s 1s/step - loss: 1.9456 - accuracy: 0.1773 - val_loss: 1.9982 - val_accuracy: 0.1667
# Epoch 3/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.9465 - accuracy: 0.1675 - val_loss: 1.9349 - val_accuracy: 0.1765
# Epoch 4/100
# 86/86 [==============================] - 86s 1s/step - loss: 1.9393 - accuracy: 0.1737 - val_loss: 1.9780 - val_accuracy: 0.1307
# Epoch 5/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.9336 - accuracy: 0.1744 - val_loss: 2.0244 - val_accuracy: 0.1569
# Epoch 6/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.9177 - accuracy: 0.1963 - val_loss: 1.9624 - val_accuracy: 0.1830
# Epoch 7/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.9114 - accuracy: 0.1952 - val_loss: 2.1085 - val_accuracy: 0.1471
# Epoch 8/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.8965 - accuracy: 0.2079 - val_loss: 2.0359 - val_accuracy: 0.1275
# Epoch 9/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.8698 - accuracy: 0.2305 - val_loss: 3.0369 - val_accuracy: 0.1732
# Epoch 10/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.8643 - accuracy: 0.2181 - val_loss: 2.1220 - val_accuracy: 0.2092
# Epoch 11/100
# 86/86 [==============================] - 88s 1s/step - loss: 1.8139 - accuracy: 0.2593 - val_loss: 1.8643 - val_accuracy: 0.2124
# Epoch 12/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.8182 - accuracy: 0.2618 - val_loss: 1.8106 - val_accuracy: 0.2614
# Epoch 13/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.7735 - accuracy: 0.2724 - val_loss: 2.1596 - val_accuracy: 0.2418
# Epoch 14/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.7533 - accuracy: 0.2924 - val_loss: 1.9266 - val_accuracy: 0.2255
# Epoch 15/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.7433 - accuracy: 0.2990 - val_loss: 1.7861 - val_accuracy: 0.3105
# Epoch 16/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.7408 - accuracy: 0.3066 - val_loss: 2.0161 - val_accuracy: 0.2941
# Epoch 17/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.7169 - accuracy: 0.2972 - val_loss: 2.5617 - val_accuracy: 0.2484
# Epoch 18/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.6893 - accuracy: 0.3325 - val_loss: 1.8283 - val_accuracy: 0.2745
# Epoch 19/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.6698 - accuracy: 0.3434 - val_loss: 1.7842 - val_accuracy: 0.2876
# Epoch 20/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.6422 - accuracy: 0.3543 - val_loss: 1.9031 - val_accuracy: 0.2778
# Epoch 21/100
# 86/86 [==============================] - 86s 1s/step - loss: 1.6124 - accuracy: 0.3693 - val_loss: 1.7888 - val_accuracy: 0.2908
# Epoch 22/100
# 86/86 [==============================] - 86s 1s/step - loss: 1.6005 - accuracy: 0.3707 - val_loss: 1.8386 - val_accuracy: 0.3268
# Epoch 23/100
# 86/86 [==============================] - 86s 1000ms/step - loss: 1.5773 - accuracy: 0.3940 - val_loss: 2.1996 - val_accuracy: 0.2908
# Epoch 24/100
# 86/86 [==============================] - 86s 1s/step - loss: 1.5521 - accuracy: 0.4050 - val_loss: 2.5520 - val_accuracy: 0.2418
# Epoch 25/100
# 86/86 [==============================] - 86s 1s/step - loss: 1.5420 - accuracy: 0.4155 - val_loss: 2.0173 - val_accuracy: 0.3072
# Epoch 26/100
# 86/86 [==============================] - 86s 1s/step - loss: 1.5311 - accuracy: 0.4068 - val_loss: 1.8718 - val_accuracy: 0.3595
# Epoch 27/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.5384 - accuracy: 0.4079 - val_loss: 1.9276 - val_accuracy: 0.3301
# Epoch 28/100
# 86/86 [==============================] - 86s 1s/step - loss: 1.4916 - accuracy: 0.4323 - val_loss: 2.1699 - val_accuracy: 0.3105
# Epoch 29/100
# 86/86 [==============================] - 86s 1s/step - loss: 1.4745 - accuracy: 0.4395 - val_loss: 1.8384 - val_accuracy: 0.3660
# Epoch 30/100
# 86/86 [==============================] - 86s 1s/step - loss: 1.4427 - accuracy: 0.4530 - val_loss: 1.7708 - val_accuracy: 0.3725
# Epoch 31/100
# 86/86 [==============================] - 86s 1000ms/step - loss: 1.3926 - accuracy: 0.4705 - val_loss: 1.7688 - val_accuracy: 0.3987
# Epoch 32/100
# 86/86 [==============================] - 86s 1s/step - loss: 1.3804 - accuracy: 0.4800 - val_loss: 2.1868 - val_accuracy: 0.2288
# Epoch 33/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.3913 - accuracy: 0.4731 - val_loss: 1.6538 - val_accuracy: 0.3693
# Epoch 34/100
# 86/86 [==============================] - 86s 999ms/step - loss: 1.3117 - accuracy: 0.5040 - val_loss: 1.7593 - val_accuracy: 0.4118
# Epoch 35/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.2890 - accuracy: 0.5138 - val_loss: 1.5027 - val_accuracy: 0.4281
# Epoch 36/100
# 86/86 [==============================] - 86s 1s/step - loss: 1.2766 - accuracy: 0.5076 - val_loss: 1.7042 - val_accuracy: 0.4020
# Epoch 37/100
# 86/86 [==============================] - 86s 998ms/step - loss: 1.2387 - accuracy: 0.5335 - val_loss: 2.0090 - val_accuracy: 0.3366
# Epoch 38/100
# 86/86 [==============================] - 86s 1000ms/step - loss: 1.2171 - accuracy: 0.5375 - val_loss: 2.5005 - val_accuracy: 0.3595
# Epoch 39/100
# 86/86 [==============================] - 86s 1000ms/step - loss: 1.1742 - accuracy: 0.5412 - val_loss: 1.8167 - val_accuracy: 0.3856
# Epoch 40/100
# 86/86 [==============================] - 87s 1s/step - loss: 1.1468 - accuracy: 0.5706 - val_loss: 2.2057 - val_accuracy: 0.4281
# Epoch 41/100
# 86/86 [==============================] - 86s 1s/step - loss: 1.1238 - accuracy: 0.5725 - val_loss: 1.6826 - val_accuracy: 0.4379
# Epoch 42/100
# 86/86 [==============================] - 86s 1s/step - loss: 1.1127 - accuracy: 0.5812 - val_loss: 1.8826 - val_accuracy: 0.4379
# Epoch 43/100
# 86/86 [==============================] - 86s 998ms/step - loss: 1.0790 - accuracy: 0.5972 - val_loss: 1.8898 - val_accuracy: 0.4183
# Epoch 44/100
# 86/86 [==============================] - 86s 999ms/step - loss: 1.0738 - accuracy: 0.5983 - val_loss: 1.7551 - val_accuracy: 0.4477
# Epoch 45/100
# 86/86 [==============================] - 86s 999ms/step - loss: 1.0353 - accuracy: 0.6158 - val_loss: 1.6061 - val_accuracy: 0.4608
# Epoch 46/100
# 86/86 [==============================] - 86s 1s/step - loss: 1.0038 - accuracy: 0.6264 - val_loss: 1.6826 - val_accuracy: 0.4346
# Epoch 47/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.9503 - accuracy: 0.6431 - val_loss: 1.7283 - val_accuracy: 0.4575
# Epoch 48/100
# 86/86 [==============================] - 86s 999ms/step - loss: 0.9298 - accuracy: 0.6457 - val_loss: 1.8081 - val_accuracy: 0.3856
# Epoch 49/100
# 86/86 [==============================] - 86s 999ms/step - loss: 0.9336 - accuracy: 0.6533 - val_loss: 2.1764 - val_accuracy: 0.4379
# Epoch 50/100
# 86/86 [==============================] - 87s 1s/step - loss: 0.9172 - accuracy: 0.6595 - val_loss: 1.9560 - val_accuracy: 0.4118
# Epoch 51/100
# 86/86 [==============================] - 86s 998ms/step - loss: 0.8729 - accuracy: 0.6832 - val_loss: 2.3502 - val_accuracy: 0.4281
# Epoch 52/100
# 86/86 [==============================] - 86s 998ms/step - loss: 0.8291 - accuracy: 0.6992 - val_loss: 2.0476 - val_accuracy: 0.4281
# Epoch 53/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.8177 - accuracy: 0.7014 - val_loss: 1.9050 - val_accuracy: 0.4444
# Epoch 54/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.8276 - accuracy: 0.7149 - val_loss: 2.3783 - val_accuracy: 0.4477
# Epoch 55/100
# 86/86 [==============================] - 86s 998ms/step - loss: 0.7776 - accuracy: 0.7174 - val_loss: 2.2463 - val_accuracy: 0.4020
# Epoch 56/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.7632 - accuracy: 0.7232 - val_loss: 1.8597 - val_accuracy: 0.4052
# Epoch 57/100
# 86/86 [==============================] - 87s 1s/step - loss: 0.7544 - accuracy: 0.7258 - val_loss: 2.1068 - val_accuracy: 0.4412
# Epoch 58/100
# 86/86 [==============================] - 87s 1s/step - loss: 0.6861 - accuracy: 0.7600 - val_loss: 2.2121 - val_accuracy: 0.4575
# Epoch 59/100
# 86/86 [==============================] - 87s 1s/step - loss: 0.6472 - accuracy: 0.7713 - val_loss: 2.1641 - val_accuracy: 0.4412
# Epoch 60/100
# 86/86 [==============================] - 87s 1s/step - loss: 0.6515 - accuracy: 0.7575 - val_loss: 2.0296 - val_accuracy: 0.4837
# Epoch 61/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.5689 - accuracy: 0.8019 - val_loss: 2.5760 - val_accuracy: 0.4477
# Epoch 62/100
# 86/86 [==============================] - 87s 1s/step - loss: 0.5368 - accuracy: 0.8088 - val_loss: 2.1686 - val_accuracy: 0.4510
# Epoch 63/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.4944 - accuracy: 0.8281 - val_loss: 2.1123 - val_accuracy: 0.4575
# Epoch 64/100
# 86/86 [==============================] - 87s 1s/step - loss: 0.5354 - accuracy: 0.8176 - val_loss: 1.8366 - val_accuracy: 0.4837
# Epoch 65/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.5283 - accuracy: 0.8172 - val_loss: 2.3354 - val_accuracy: 0.4804
# Epoch 66/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.4680 - accuracy: 0.8405 - val_loss: 2.4504 - val_accuracy: 0.4346
# Epoch 67/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.4959 - accuracy: 0.8369 - val_loss: 2.0736 - val_accuracy: 0.4641
# Epoch 68/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.4342 - accuracy: 0.8489 - val_loss: 2.4915 - val_accuracy: 0.4739
# Epoch 69/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.4458 - accuracy: 0.8467 - val_loss: 2.3232 - val_accuracy: 0.4739
# Epoch 70/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.3995 - accuracy: 0.8685 - val_loss: 2.4823 - val_accuracy: 0.4771
# Epoch 71/100
# 86/86 [==============================] - 87s 1s/step - loss: 0.3724 - accuracy: 0.8824 - val_loss: 2.2219 - val_accuracy: 0.5163
# Epoch 72/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.3275 - accuracy: 0.8988 - val_loss: 2.6897 - val_accuracy: 0.4837
# Epoch 73/100
# 86/86 [==============================] - 87s 1s/step - loss: 0.3102 - accuracy: 0.8951 - val_loss: 2.4264 - val_accuracy: 0.4575
# Epoch 74/100
# 86/86 [==============================] - 86s 999ms/step - loss: 0.3089 - accuracy: 0.9101 - val_loss: 2.5795 - val_accuracy: 0.4510
# Epoch 75/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.2856 - accuracy: 0.9115 - val_loss: 2.6524 - val_accuracy: 0.4542
# Epoch 76/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.2808 - accuracy: 0.9068 - val_loss: 2.7451 - val_accuracy: 0.4314
# Epoch 77/100
# 86/86 [==============================] - 86s 999ms/step - loss: 0.2814 - accuracy: 0.9108 - val_loss: 2.8660 - val_accuracy: 0.4641
# Epoch 78/100
# 86/86 [==============================] - 86s 997ms/step - loss: 0.2478 - accuracy: 0.9199 - val_loss: 2.6870 - val_accuracy: 0.4477
# Epoch 79/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.2165 - accuracy: 0.9381 - val_loss: 2.7723 - val_accuracy: 0.4412
# Epoch 80/100
# 86/86 [==============================] - 87s 1s/step - loss: 0.1970 - accuracy: 0.9377 - val_loss: 2.7971 - val_accuracy: 0.4542
# Epoch 81/100
# 86/86 [==============================] - 87s 1s/step - loss: 0.2275 - accuracy: 0.9264 - val_loss: 3.3096 - val_accuracy: 0.4314
# Epoch 82/100
# 86/86 [==============================] - 87s 1s/step - loss: 0.2259 - accuracy: 0.9355 - val_loss: 2.5664 - val_accuracy: 0.4673
# Epoch 83/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.2383 - accuracy: 0.9279 - val_loss: 2.6053 - val_accuracy: 0.4510
# Epoch 84/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.1970 - accuracy: 0.9417 - val_loss: 3.0405 - val_accuracy: 0.4673
# Epoch 85/100
# 86/86 [==============================] - 86s 1s/step - loss: 0.2554 - accuracy: 0.9243 - val_loss: 2.8119 - val_accuracy: 0.4379
# Epoch 86/100
# 86/86 [==============================] - ETA: 0s - loss: 0.1998 - accuracy: 0.9366Restoring model weights from the end of the best epoch: 71.
# 86/86 [==============================] - 86s 996ms/step - loss: 0.1998 - accuracy: 0.9366 - val_loss: 2.8283 - val_accuracy: 0.4673
# Epoch 86: early stopping

# %%
model_dir = "models/model2_CNN"
model.save(model_dir)
with open("history/model2_CNN.json", "w") as json_file:
    json.dump(history.history, json_file)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 17). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/model2_CNN\assets
# INFO:tensorflow:Assets written to: models/model2_CNN\assets

# %%
# with open("history/model2_CNN.json", "r") as json_file:
#     history = json.load(json_file)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# filename = "models/model2_CNN"
# model = load_model(filename)
prediction = model.predict(x = test_image, batch_size = 10, verbose = 0)

# %%
predicted_labels = np.argmax(prediction, axis=1)
label_map = {0: 'angry', 1: 'disgust', 2: 'fear', 3: 'happy', 4: 'neutral', 5: 'sad', 6: 'surprise'}
true_labels = np.argmax(test_emotion_onehot, axis=1)
num_of_wrong_predictions = 0

invalid_prediction = []
invalid_prediction_emotion = []
invalid_emotion = []

for i in range(len(test_emotion)):
    if label_map[true_labels[i]] != label_map[predicted_labels[i]]:
        invalid_prediction.append(test_image[i])
        invalid_prediction_emotion.append(prediction[i])
        invalid_emotion.append(test_emotion[i])


print(f"Accuracy:{len(invalid_emotion)/len(test_emotion)}")

invalid_prediction = np.array(invalid_prediction)
invalid_prediction_emotion = np.array(invalid_prediction_emotion)
invalid_emotion = np.array(invalid_emotion)
# Out:
# Accuracy:0.5263835263835264

# %%
import matplotlib.pyplot as plt

wrong_predictions_per_emotion = {'angry': 0, 'disgust': 0, 'fear': 0, 'happy': 0, 'neutral': 0, 'sad': 0, 'surprise': 0}

for i in range(len(invalid_emotion)):
    true_label = label_map[true_labels[i]]
    predicted_label = label_map[predicted_labels[i]]
    if true_label != predicted_label:
        wrong_predictions_per_emotion[true_label] += 1

plt.bar(wrong_predictions_per_emotion.keys(), wrong_predictions_per_emotion.values())
plt.xlabel('Emotion')
plt.ylabel('Number of wrong predictions')
plt.show()

# %%
import matplotlib.pyplot as plt

wrong_predictions_per_emotion = {'angry': 0, 'disgust': 0, 'fear': 0, 'happy': 0, 'neutral': 0, 'sad': 0, 'surprise': 0}
test_cases_per_emotion = {'angry': 0, 'disgust': 0, 'fear': 0, 'happy': 0, 'neutral': 0, 'sad': 0, 'surprise': 0}
ratio_of_wrong_predictions = {'angry': 0, 'disgust': 0, 'fear': 0, 'happy': 0, 'neutral': 0, 'sad': 0, 'surprise': 0}

for i in range(len(invalid_emotion)):
    true_label = label_map[true_labels[i]]
    predicted_label = label_map[predicted_labels[i]]
    test_cases_per_emotion[true_label] += 1
    if true_label != predicted_label:
        wrong_predictions_per_emotion[true_label] += 1

for emotion in emotions:
    ratio_of_wrong_predictions[emotion] = wrong_predictions_per_emotion[emotion] / test_cases_per_emotion[emotion]

plt.bar(ratio_of_wrong_predictions.keys(), ratio_of_wrong_predictions.values())
plt.xlabel('Emotion')
plt.ylabel('Ratio of wrong predictions')
plt.show()
